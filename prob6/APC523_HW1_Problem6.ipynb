# %% [markdown]
# # APC 523 HW 1 Problem 6

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
arr = np.linspace(0.0, 1.0, 1001)

# %%
sqarr = arr
NLOOPS = 52
for i in range(NLOOPS):
    sqarr = np.sqrt(sqarr)
for i in range(NLOOPS):
    sqarr = sqarr**2

plt.figure(figsize=(7,6))
plt.plot(arr, sqarr, label='{:d} successive sqrts and sqs'.format(NLOOPS))
plt.plot(arr, arr, linestyle='dashed', color='gray')
plt.legend(fontsize=12)
plt.savefig('sqrt_52.png')

# %%
uniq_sqarr = np.unique(sqarr)
uniq_sqarr
# Out:
# array([0.00000000e+00, 9.11881932e-04, 1.50343911e-03, 2.47875207e-03,
#        4.08677133e-03, 6.73794685e-03, 1.11089965e-02, 1.83156383e-02,
#        3.01973829e-02, 4.97870673e-02, 8.20849977e-02, 1.35335281e-01,
#        2.23130158e-01, 3.67879438e-01, 6.06530657e-01, 1.00000000e+00])

# %%
res = uniq_sqarr[-2]
for i in range(NLOOPS):
    res = np.sqrt(res)
print(res)
# Out:
# 0.9999999999999999

# %%
float.hex(res)
# Out:
# '0x1.fffffffffffffp-1'

# %%
res = uniq_sqarr[-3]
for i in range(NLOOPS):
    res = np.sqrt(res)
print(float.hex(res))
# Out:
# 0x1.ffffffffffffep-1

# %%
for sq_res in uniq_sqarr:
    for i in range(NLOOPS):
        sq_res = np.sqrt(sq_res)
    print(float.hex(sq_res))
# Out:
# 0x0.0p+0
# 0x1.ffffffffffff2p-1
# 0x1.ffffffffffff3p-1
# 0x1.ffffffffffff4p-1
# 0x1.ffffffffffff5p-1
# 0x1.ffffffffffff6p-1
# 0x1.ffffffffffff7p-1
# 0x1.ffffffffffff8p-1
# 0x1.ffffffffffff9p-1
# 0x1.ffffffffffffap-1
# 0x1.ffffffffffffbp-1
# 0x1.ffffffffffffcp-1
# 0x1.ffffffffffffdp-1
# 0x1.ffffffffffffep-1
# 0x1.fffffffffffffp-1
# 0x1.0000000000000p+0

# %%
res = float.fromhex('0x1.ffffffffffff2p-1')
(np.sqrt(res)).hex()
# Out:
# '0x1.ffffffffffff9p-1'

# %%
sqarr = arr
NLOOPS = 53
for i in range(NLOOPS):
    sqarr = np.sqrt(sqarr)
for i in range(NLOOPS):
    sqarr = sqarr**2

plt.figure(figsize=(7,6))
plt.plot(arr, sqarr, label='{:d} successive sqrts and sqs'.format(NLOOPS))
plt.plot(arr, arr, linestyle='dashed', color='gray')
plt.legend(fontsize=12)
plt.savefig('sqrt_53.png')

# %%
np.unique(sqarr)
# Out:
# array([0.00000000e+00, 9.11881932e-04, 2.47875207e-03, 6.73794685e-03,
#        1.83156383e-02, 4.97870673e-02, 1.35335281e-01, 3.67879438e-01,
#        1.00000000e+00])
